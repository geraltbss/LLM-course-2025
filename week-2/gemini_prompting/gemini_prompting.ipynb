# %% [markdown]
# <a href="https://colab.research.google.com/github/geraltbss/LLM-course-2025/blob/main/week-2/gemini_prompting/gemini_prompting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prompting with Gemini
# Notebook for experimenting different promting techniques with Gemini

# %% [markdown]
# Install the required dependencies with the following command.

# %%
#%pip install google-generativeai

# %% [markdown]
# Import the required libraries.

# %%
import google.generativeai as genai
import os
from google.colab import userdata

# %% [markdown]
# Insert your Gemini API key to the following command and import the Gemini model.

# %%
# API_KEY = os.environ.get("GEMINI_API_KEY")
API_KEY = userdata.get('Gemini')
genai.configure(api_key=API_KEY)

LLM = "gemini-2.0-flash"
model = genai.GenerativeModel(LLM)

# %% [markdown]
# Modify the `system_prompt` to experiment with different prompting approaches.

# %%
system_prompt = "Hello! You are a helpful and concise assistant."

# %% [markdown]
# We create a list of messages so that we keep history in the context. If you want to clear the messages later in this notebook, add the line `messages = []` to a new line cell in the notebook.

# %%
messages = []
messages.append(system_prompt)

# %% [markdown]
# Get the response from Gemini model by providing the prompt in a messages list to it.

# %%
r = model.generate_content(messages).text

# %% [markdown]
# Print the output of the model.

# %%
print(r)
# Out:
# Okay, I understand. I will strive to be helpful and concise in my responses. How can I assist you today?

# %% [markdown]
# Let's define a new prompt.

# %%
user_input = "Generate the best possible prompt to make an LLM write an easy to understand blog post explaining how MLB players are drafted, focusing on the financial elements like bonuses, contracts, and team budgets. The prompt should request a friendly tone and clear explanations for non experts."

# %% [markdown]
# Let's add athe new prompt to the messages list.

# %%
messages.append(user_input)

# %% [markdown]
# Again we generate the output with the Gemini model.

# %%
r = model.generate_content(messages).text

# %% [markdown]
# ... and print the output.

# %%
print(messages)
# Out:
# ['Hello! You are a helpful and concise assistant.', 'Write a blog post explaining how Major League Baseball (MLB) players get drafted and how money influences the process. Describe how teams choose players, how signing bonuses work, and why draft position affects future income. Use a friendly, easy to read tone for people new to baseball.', "Example 1:'Every summer, MLB teams go shopping, not for cars, but for players. The MLB Draft lets teams pick young talents, hoping to find the next superstar. The higher you’re drafted, the bigger your signing bonus, sometimes millions before you even swing a bat.' Example 2:'The MLB draft isn’t just about skill; it’s also about strategy and budgets. Teams must balance their draft pools, negotiate contracts, and avoid overpaying. It’s like a mix of scouting and stock investing, but the assets can hit home runs. Task: 'Now write a full blog post explaining how MLB players are drafted and how finances influence the process. Keep the tone friendly, 
# ...

# %%
print(r)
# Out:
# Okay, let's break this down.
#
# **Prompt 1: Blog Title Ideas**
#
# Here are five catchy, beginner-friendly blog titles about the MLB draft and player pay:
#
# 1.  **MLB Draft 101: From High School Hero to Pro Paycheck!**
# 2.  **Swing for the Green: How MLB Teams Draft and Pay Future Stars.**
# 3.  **Draft Day Dreams: A Beginner's Guide to MLB's Talent Grab.**
# 4.  **Baseball's Billion-Dollar Baby Hunt: Understanding the MLB Draft.**
# 5.  **Beyond the Diamond: The Moneyball of the MLB Draft Explained.**
#
# **Prompt 2: Three-Paragraph Blog Post (Using Title #1)**
#
# **MLB Draft 101: From High School Hero to Pro Paycheck!**
#
# ...

# %% [markdown]
# **Zero-shot prompting output:**
#
# Okay, here's a blog post explaining the MLB draft and the role of money:
#
# ## From College Diamond to MLB Dreams: How the Draft Works (and Where the Money Comes In!)
#
# So, you're a baseball fan! That's awesome. Ever wonder how future MLB stars go from playing college ball to hitting home runs in the big leagues? It all starts with the **MLB Draft!** Think of it like a giant, annual talent show where all 30 MLB teams get to pick the best young baseball players in the country (and sometimes beyond!). Let's break down how it works:
#
# **The Draft: A Game of Selection**
#
# Every year, usually in July, MLB teams take turns selecting players in a multi-round draft. The order is determined by the previous season's standings – the team with the worst record gets the first pick, and so on. This is designed to give struggling teams a chance to improve by nabbing top talent.
#
# **How Do Teams Choose? Scouting!**
#
# Teams spend *tons* of time and money scouting amateur players. They look at everything:
#
# *   **Skill:** Can they hit? Can they throw? Are they fast?
# *   **Physical Attributes:** Are they tall? Strong? Do they have the right build for a position?
# *   **Potential:** How much better can they get? This is a huge factor. Teams are trying to predict who will be a star in a few years, not just who's good right now.
# *   **Character:** Are they coachable? Do they work hard? Are they good teammates?
#
# All this information goes into a "draft board," where teams rank players and decide who they want to select.
#
# **The Signing Bonus: Welcome to the Pros!**
#
# Once a player is drafted, the team offers them a contract, usually with a **signing bonus.** This is a lump sum of money the player receives for signing the contract. The higher you're drafted, the bigger the bonus generally is.
#
# MLB has a "slot value" system. This is a recommended bonus amount for each draft pick. Teams don't *have* to stick to these values, but they usually do. Over or underspending can come with penalties (like losing future draft picks). This system is designed to create some fairness and prevent teams from spending unlimited money on amateur players.
#
# **Why Draft Position Matters (Big Time!)**
#
# Draft position is directly related to future income potential. Here's why:
#
# *   **Bigger Signing Bonus:** Players picked higher typically get significantly larger signing bonuses. This is their first big payday!
# *   **Faster Track to the Majors:** Higher draft picks are often given more opportunities to develop within the team's system. They might be promoted to higher levels of minor league ball more quickly, putting them on a faster track to the MLB.
# *   **More Publicity and Recognition:** Being a top draft pick comes with a lot of attention. This can lead to endorsement deals and other opportunities down the line.
#
# **The Money Factor: It's More Than Just the Bonus**
#
# While the signing bonus is the immediate cash, the *potential* for future earnings is the real prize. Making it to the MLB means:
#
# *   **MLB Salaries:** Even the minimum MLB salary is significantly higher than minor league pay.
# *   **Endorsement Deals:** Star players can earn millions from endorsements with companies like Nike, Adidas, or Gatorade.
# *   **Long-Term Contracts:** Once a player proves themselves in the MLB, they can negotiate lucrative long-term contracts, guaranteeing them millions of dollars over several years.
#
# **In Conclusion:**
#
# The MLB draft is a complex process, but it's the gateway to a professional baseball career. Teams rely on extensive scouting to identify talent, and the draft position directly impacts a player's signing bonus and future earnings potential. While talent and hard work are essential, the draft is the first step in the journey from amateur player to MLB star, and the money involved makes it a high-stakes game for everyone involved!

# %% [markdown]
# **Few-shots prompting output:**
#
# ## Calling All Future Stars: How the MLB Draft Works (and How Money Talks!)
#
# Ever wonder how those fresh-faced rookies suddenly appear on your favorite MLB team? Well, it's all thanks to the MLB Draft! Think of it like a giant talent show, but instead of singing and dancing, it's all about baseball. Every summer, Major League Baseball teams get to pick the best young players coming out of high school and college, hoping to snag the next Mike Trout or Shohei Ohtani.
#
# So, how does this whole "draft" thing work? Let's break it down in a way that even your grandma (who thinks a "walk-off" is when someone leaves the room) can understand.
#
# **The Draft Order: First Pick Gets First Dibs!**
#
# The draft order is determined by the previous season's standings. The team with the worst record gets the first pick, meaning they have the first shot at choosing the best player available. This gives struggling teams a chance to rebuild. Think of it as a consolation prize for a crummy season. The better a team performed the previous season, the later they pick. It's designed to keep things (relatively) fair.
#
# **Scouting: It's More Than Just Watching Games**
#
# Before the draft, teams spend months (sometimes years!) scouting players. This isn't just watching games; it's a deep dive into a player's skills, stats, personality, and even their family history (okay, maybe not *that* deep, but teams want to know what they're getting!). Scouts look at everything from how hard they throw a fastball to how quickly they can run to first base, and even how well they handle pressure. It’s like being a detective, but instead of solving crimes, they're finding diamonds in the rough.
#
# **Making the Pick: Balancing Skill and Need**
#
# On draft day, teams make their picks, one at a time. They consider several factors:
#
# *   **Talent:** Is this player a potential superstar?
# *   **Position:** Does the team need a shortstop, a pitcher, or a designated hitter who can also bake a mean apple pie?
# *   **Signability:** Can the team afford to sign the player to a contract? (More on this juicy part later!)
#
# Teams often have a "wish list" of players, but they have to be flexible. Sometimes their top pick is snatched up by another team, forcing them to adjust their strategy on the fly.
#
# **The Moneyball Effect: How Finances Change Everything**
#
# Okay, let's talk money! This is where things get really interesting. Each team has a "draft pool," which is a set amount of money they can spend on signing bonuses for their drafted players. Signing bonuses are essentially a lump sum of money paid to a player when they sign their first professional contract.
#
# Here's the kicker: The higher you're drafted, the bigger the recommended signing bonus. The #1 overall pick gets a *massive* bonus compared to someone picked in the 20th round. For some players, it can be life-changing money!
#
# **Why Draft Position Matters: Beyond the Bonus**
#
# Draft position affects more than just the initial signing bonus. A higher draft pick often gets:
#
# *   **Faster Track to the Majors:** Teams are more likely to invest time and resources in developing a top draft pick, giving them a quicker path to the big leagues.
# *   **More Opportunities:** They’ll likely get more chances to prove themselves and make mistakes without being cut early.
# *   **Prestige and Recognition:** Being a high draft pick comes with bragging rights and increased attention from fans and media.
#
# **Draft Strategy: Where Math Meets Baseball**
#
# Teams have to be strategic about how they allocate their draft pool money. They might:
#
# *   **Splurge on a Top Pick:** Spend a big chunk of their pool to sign a potential superstar.
# *   **Spread the Wealth:** Sign several mid-round players for slightly less than their recommended bonuses, hoping to find hidden gems.
# *   **Undersign and Oversign:** Spend less on some players to be able to offer more to other players they really want.
#
# It's a delicate balancing act, and teams are constantly trying to find the best value for their money.
#
# **The Bottom Line: Skill + Opportunity + Money = MLB Dream**
#
# The MLB Draft is a complex process that combines talent evaluation, strategic planning, and a whole lot of money. While skill is undeniably important, draft position and signing bonuses play a huge role in shaping a young player's career. It's not just about being good; it's about being in the right place at the right time, and maybe even getting a little lucky along the way. So, next time you're watching a baseball game, remember that every player on the field has a unique story – a journey that often begins with a phone call on draft day.

# %% [markdown]
# **CoT prompting output:**
#
# Okay, here's a blog post breaking down the MLB Draft and how money plays a huge role in it, aimed at baseball newbies:
#
# **So, You Wanna Know How Baseball Players Get Drafted (and Paid)? Let's Talk MLB!**
#
# Ever wonder how those young phenoms suddenly appear in Major League Baseball? It's not magic (though some of their plays sure seem like it!). It all starts with the MLB Draft, baseball's version of a talent supermarket. Think of it as a yearly shopping spree where teams get to pick the best young players available.
#
# **Who Gets to Enter the Draft?**
#
# Basically, anyone who's good enough and eligible can enter! We're talking high school players who've graduated or turned 19, college players after their junior year, or any four-year college player who is at least 21 years old. International players also fall under this process, although their signing process is slightly different and not tied to the draft order in the same way. Basically, if you're showing serious promise on the diamond, MLB teams have their eyes on you!
#
# **How Do Teams Pick Players? (And Why Does My Team Always Pick Last?)**
#
# The draft order is (generally) determined by the previous season's record. The team with the *worst* record gets the first pick (lucky them!), and it goes down the line to the World Series winner picking last (poor them!). It's designed to give struggling teams a chance to rebuild by grabbing top talent. This is also why teams sometimes are accused of "tanking," intentionally losing games to get a better draft pick the following year. (Don't tell anyone I told you that!).
#
# Teams have scouting departments who spend countless hours watching, analyzing, and evaluating these young players. They look at everything: hitting, pitching, fielding, speed, even personality! They try to predict who will be the next superstar. Teams can also trade draft picks to move up or down in the draft order, adding another layer of strategy.
#
# **Show Me the Money! (Signing Bonuses and Contracts)**
#
# Okay, this is where it gets interesting. When a player is drafted, the team offers them a contract, which usually includes a *signing bonus*. Think of it as a "Welcome to the Big Leagues!" check. The higher you're drafted, the bigger that bonus tends to be. First overall picks are talking millions of dollars *before* they've even played a single professional game.
#
# The MLB sets suggested values, called "slot values," for each draft pick. This helps teams manage their overall spending because each team has a limited "draft pool" – a total amount they can spend on signing bonuses for their draft picks. If a team goes over their draft pool, they face penalties. It’s a delicate balancing act of scouting potential and managing the team budget!
#
# Negotiations are crucial. Players (often with agents) try to get the biggest bonus possible, while teams try to stay within their budget and get the player to sign for a reasonable amount. These negotiations can sometimes get tricky, with players sometimes choosing to go back to college for another year to improve their stock and potentially get drafted higher the following year.
#
# **Why Draft Position Matters (Beyond the Bragging Rights)**
#
# Being drafted early has a *huge* impact on a player's career trajectory and potential earnings. Here's why:
#
# *   **Bigger Signing Bonus:** Obvious, right? More money upfront is always a good thing!
# *   **Faster Track to the Majors:** Teams are more likely to invest in developing high draft picks, meaning they often get moved through the minor league system more quickly.
# *   **More Opportunities:** Early draftees usually get more playing time in the minors, giving them a better chance to prove themselves and reach the big leagues.
# *   **Increased Endorsement Potential:** A high draft pick brings instant attention, making them more attractive to sponsors and opening up endorsement deals.
#
# In short, a higher draft position equals more opportunities, faster advancement, and ultimately, a much bigger payday down the road. While skill and hard work are essential, where you're drafted can significantly impact your baseball journey!
#
# So, there you have it! The MLB Draft is a complex system where talent meets finance. It's a high-stakes game that can change a player's life forever, and one that keeps baseball fans like us glued to our seats every year. Now you're armed with the knowledge to understand the draft and appreciate its impact on the future of the game. Go team!

# %% [markdown]
# **Prompt chaining output:**
#
# Okay, here we go!
#
# **Prompt 1: Five Catchy Blog Title Ideas**
#
# Here are five blog title ideas about the MLB draft and money, designed to be catchy and beginner-friendly:
#
# 1.  **Draft Dreams & Dollar Signs: How MLB Teams Pick (and Pay) Their Future Stars**
# 2.  **From High School Hero to Pro Paycheck: Cracking the MLB Draft Code**
# 3.  **Swing for the Fences... and the Big Bucks! Understanding the MLB Draft Lottery**
# 4.  **MLB Draft 101: Where Baseball Dreams Meet Cold, Hard Cash**
# 5.  **Scouts, Stats, and Signing Bonuses: Demystifying the MLB Draft Process**
#
# **Prompt 2: Blog Post on MLB Draft and Finances (Using Title #1)**
#
# **Draft Dreams & Dollar Signs: How MLB Teams Pick (and Pay) Their Future Stars**
#
# Every June, Major League Baseball teams do a little shopping. But instead of browsing for new bats or gloves, they're picking future players in the MLB Draft! Think of it like a fantasy league, but way more serious. Teams get to select talented young athletes – high schoolers, college players, and even some international prospects – hoping to find the next Mike Trout or Shohei Ohtani. The order they pick in is determined by the reverse order of their previous season's standings – the team with the worst record gets the first pick, offering them the first crack at landing a potential superstar. This draft is a huge deal because it sets the stage for a player's entire career, both on and off the field.
#
# So, how do teams actually choose who to draft? It's a mix of art and science. They use scouts who watch players in action, evaluating their hitting, pitching, fielding, and running abilities. They also dive into stats – batting averages, ERAs, exit velocities – trying to predict how a player will perform at the professional level. But it's not just about talent; teams also consider a player's personality, work ethic, and how well they might fit into the team's culture. And let’s be honest, it's a HUGE gamble. These players are young and haven't proven anything in the majors yet!
#
# The real game-changer in the draft is the money. When a player is drafted, they negotiate a signing bonus with the team. These bonuses can range from a few thousand dollars for later-round picks to millions for the top selections. The higher you're drafted, the bigger the bonus, because the team believes you have the potential to become a star. This bonus is often just the start, with a team planning on keeping the player on their roster for several years, and a player in turn hoping to improve their skills enough to make a lucrative long-term contract in the future. Draft position significantly impacts a player's long-term earnings potential because it sets the bar for future contract negotiations and endorsements. Teams are more likely to invest in developing high draft picks, providing them with more opportunities to succeed and ultimately earn bigger paychecks.

# %% [markdown]
# **Tree of thought prompting output:**
#
# Okay, let's get this blog post drafted!
#
# **Prompt 1: Blog Title Ideas**
#
# Here are five title ideas that are catchy and beginner-friendly:
#
# 1.  **"Swing for the Green: How MLB Drafts Work (and the Money Behind Them)"**
# 2.  **"From Sandlot to Signing Bonus: A Beginner's Guide to the MLB Draft"**
# 3.  **"Draft Day Dreams: Unpacking MLB's Player Selection and Payday System"**
# 4.  **"The MLB Draft: Where Baseball Talent Meets Big Bucks"**
# 5.  **"Drafting the Future: How MLB Teams Pick (and Pay) Their Stars"**
#
# **Prompt 2: Blog Post (Based on Title #1)**
#
# **"Swing for the Green: How MLB Drafts Work (and the Money Behind Them)"**
#
# Ever wonder how your favorite baseball stars made it to the big leagues? A huge piece of the puzzle is the MLB Draft! Think of it like a yearly shopping spree where each MLB team gets to pick the best young baseball talent available. This isn't just about skill; it's a carefully orchestrated process with tons of money involved. High school players, college players, and even international players are all eligible, making it a global search for the next superstar.
#
# So, how does it all work? Every team gets a turn to choose players, and the order is based on the previous season's standings. The team with the worst record gets the first pick, and so on. It’s kind of like getting the first pick in fantasy football, but instead of picking quarterbacks, they're grabbing potential future Cy Young winners. This draft position is *super* important because it directly impacts how much money a player can make.
#
# Once a player is drafted, the real fun begins: contract negotiations! This is where signing bonuses come in – a lump sum of money a player receives for agreeing to join a team. The higher a player is drafted, the larger the signing bonus they can command. It’s not just bragging rights; it’s real money, sometimes millions of dollars before they've even played a single MLB game. This initial bonus sets the stage for their future earnings, so landing high in the draft is a HUGE deal!
#
# **Three Different Ways to Explain the MLB Draft and Finances**
#
# 1.  **As a Behind-the-Scenes Story of How Teams 'Invest' in Young Talent:**
#
#     *   **Focus:** Emphasize scouting, risk assessment, long-term player development, and team budget constraints. Frame it as a "portfolio" of young players.
#     *   **Tone:** Business-like but accessible. Use terms like "ROI" (Return on Investment) in an explained way.
#     *   **Example:** "MLB teams don't just pick players; they *invest* in them. Their scouting departments are like research analysts, digging deep to find undervalued talent. A draft pick is like buying stock in a promising company. Some will skyrocket, and some will bust, but the goal is to build a winning team."
#
# 2.  **As a Step-by-Step Financial Breakdown of the Drafting Process:**
#
#     *   **Focus:** Detail the mechanics of the draft, slot values, bonus pools, luxury taxes, and the impact of Collective Bargaining Agreements (CBAs).
#     *   **Tone:** More technical but still approachable. Use charts, bullet points, and clear definitions.
#     *   **Example:** "Let's break down the financial side of the MLB Draft. Each draft slot has a 'suggested bonus' value. Teams have a total 'bonus pool' they can spend on signing bonuses without facing penalties. Going over that pool triggers luxury taxes... and that's where things get complicated!"
#
# 3.  **As a Humorous Take Comparing Draft Picks to Startup Investments:**
#
#     *   **Focus:** Use analogies to the tech world, like "scouting is like venture capital research," "draft picks are like seed-stage startups," and "busts are like failed tech companies."
#     *   **Tone:** Lighthearted, witty, and full of relatable examples.
#     *   **Example:** "Think of the MLB Draft as 'Shark Tank' for baseball players. Scouts are the investors, and the young players are the pitching entrepreneurs. Some pitches are brilliant (a fastball that clocks 100 mph!), while others are... well, let's just say they need a lot of work. The bonus is the investment and if the "company" makes it to the big leagues, everyone gets rich!
#
# **Evaluation and Best Approach**
#
# For beginners, the **humorous take comparing draft picks to startup investments** is likely the most effective. Here's why:
#
# *   **Relatability:** Many people are familiar with the concept of startup investments and the inherent risks and rewards. The comparison provides a framework for understanding the complexities of the MLB draft.
# *   **Engagement:** Humor makes the topic more approachable and less intimidating. It helps break down complex concepts into easier-to-digest pieces.
# *   **Memorability:** Funny analogies are more likely to stick in people's minds, which aids in long-term learning.
#
# Let's write that blog post now!
#
# **Blog Post: "MLB Draft: Baseball's Shark Tank"**
#
# Ever wonder how future baseball legends make it to the majors? It all starts with the MLB Draft, which is essentially "Shark Tank" for baseball players. Scouts are like venture capitalists, teams are investing firms, and young prospects are the entrepreneurs pitching their talents!
#
# The premise is simple: each MLB team gets to "invest" in promising young talent. Scouts, the venture capitalists, are constantly scouring the globe, evaluating high school and college players. They're looking for the next big thing, the player with the potential to be a superstar. This is the research phase, looking at every stat, scouting every game, and talking to every coach to see who has the potential.
#
# Then comes draft day, the day that the investors make their decision. The best player is the player who is believed to be the next baseball "startup". But it doesn't always turn out well. Just like in the real world, not every startup succeeds. Some players pan out, becoming All-Stars and World Series champions. Others never make it to the majors, becoming what we call "busts" - a startup that didn't quite make it. But when they do make it, it's like watching a stock go from seed funding to an IPO. A world series IPO at that!

# %% [markdown]
# **Self prompting output:**
#
# Okay, let's break this down.
#
# **Prompt 1: Blog Title Ideas**
#
# Here are five catchy, beginner-friendly blog titles about the MLB draft and player pay:
#
# 1.  **MLB Draft 101: From High School Hero to Pro Paycheck!**
# 2.  **Swing for the Green: How MLB Teams Draft and Pay Future Stars.**
# 3.  **Draft Day Dreams: A Beginner's Guide to MLB's Talent Grab.**
# 4.  **Baseball's Billion-Dollar Baby Hunt: Understanding the MLB Draft.**
# 5.  **Beyond the Diamond: The Moneyball of the MLB Draft Explained.**
#
# **Prompt 2: Three-Paragraph Blog Post (Using Title #1)**
#
# **MLB Draft 101: From High School Hero to Pro Paycheck!**
#
# Every summer, Major League Baseball teams embark on a mission to find the next generation of superstars. This isn't done through tryouts, but through the MLB Draft. Think of it as a yearly shopping spree where teams get to pick talented amateur players – high schoolers, college players, and even some international prospects. The draft order is determined by the previous season's standings, with the worst team getting the first pick (think of it as a consolation prize!). The higher you’re picked, the more attention and potential money comes your way.
#
# But how does it all work? Teams have scouting departments that spend countless hours watching and evaluating players. They consider everything: hitting ability, pitching prowess, fielding skills, and even things like personality and work ethic. Once the draft begins, teams take turns selecting players based on their rankings and needs. This isn’t just about finding the best player available; it's also about fitting that player into their team's long-term plan and budget.
#
# And speaking of budget, here's where the "pro paycheck" comes in. When a player is drafted, the team offers them a contract that includes a signing bonus. These bonuses can range from a few thousand dollars for late-round picks to millions for the top selections. It's a huge financial decision for both the player and the team, as the team needs to manage its overall draft pool (a total budget for all their draft picks), and the player needs to decide if the offer is fair based on their perceived value. A higher draft position usually means a bigger bonus and potentially a faster track to the big leagues, affecting their earning potential for years to come.
#
# **Three Explanations of the Draft Process & Finances:**
#
# *   **Behind-the-Scenes Story: "Investing" in Young Talent:** Imagine MLB teams are like venture capitalists investing in promising startups. Each draft pick is a potential home-run-hitting, Cy Young-winning "company." Teams scout, analyze "market potential" (player skill), and negotiate investment terms (signing bonus). They then nurture the "company" (develop the player) hoping for a massive return on investment (championships and revenue). The draft pool is their investment fund, and the GM is the managing partner deciding where to allocate resources.
# *   **Step-by-Step Financial Breakdown:** 1. Teams get a draft pool based on the prior season's record. 2. Scouts evaluate talent and assign values to players. 3. Teams select players in order. 4.  Negotiations occur between the team and player's agent (or family). 5. A signing bonus is agreed upon (part of the overall draft pool limit). 6. The player is added to the team's minor league system (an ongoing cost). 7. If successful, the player reaches the majors and receives a major league salary (a major investment requiring careful financial planning.)
# *   **Humorous Take (Draft Picks as Startup Investments):** "Okay, scouts are like baseball stockbrokers constantly chasing prospects. They go to games instead of meetings, talk about batting averages instead of quarterly earnings, and their investments swing for the fences or strikeout looking. The first pick is like the IPO of the century; everyone wants it, but the pressure is immense. Signing bonuses?  That’s the seed funding. Minor leagues?  The incubator.  Hopefully, after years of nurturing, you get a player who's worth more than your initial investment...or, you might just end up with a $10 million bust."
#
# **Evaluation:**
#
# The "Investing in Young Talent" angle probably works best for beginners. It provides a relatable framework and avoids getting bogged down in too many technical details. It makes the process feel less like a complex set of rules and more like a strategic decision.
#
# **Best Prompt to Make an LLM Write a Blog Post:**
#
# Write a blog post explaining how Major League Baseball (MLB) players get drafted and how money influences the process, targeting readers who are new to baseball.
#
# Use a friendly and slightly humorous tone. Explain the following:
#
# *   **What is the MLB Draft?** Explain what it is, who is eligible, and how the draft order is determined.
# *   **How Teams Select Players:** Describe the scouting process and factors teams consider when making draft picks (skill, potential, team needs, etc.).
# *   **Signing Bonuses and Contracts:** Explain how signing bonuses work, what a draft pool is, and the negotiation process.
# *   **Financial Impact on a Player's Career:** Explain how draft position affects a player's earning potential and career trajectory.
#
# Present the information in a way that compares MLB teams to venture capitalists investing in promising "startups" (the players). Each draft pick is a potential home-run-hitting, Cy Young-winning "company." The draft pool is their investment fund.
#
# Use simple language, analogies, and real-world examples to help readers understand the concepts. Avoid overly technical jargon.
#
# The goal is to create an engaging and informative piece that demystifies the MLB draft and its financial aspects for a non-expert audience.
